# %% [markdown]
# # <font color = Green > Reasons for visiting Saudi Arabia and its cost </font>

# %% [markdown]
# # <font color = red >  University of Hafr Al-Batin </font>
# ## <font color = red >  College of computer sceince and engineering </font>
# ## <font color = red >    DSC 233 Data management and analysis Project </font>
#
# ## <font color = red >  Ahmed Adnan - 2200000997 </font>
#
#
# ## <font color = red >  Booking.com Saudi Arabia 2021 </font>
#
# ## <font color = red >  data information </font>
# - The First dataset which is  about Hotels dataset for Saudi Arabia from Booking.com it is about data of 1443 hotels in Saudi Arabian on date 17 Oct 2021.
# you can download dataset :  https://www.kaggle.com/datasets/asafarji/saudi-arabia-bookingcom-2021?resource=download.
#
# ## <font color = red >  The main indicators of tourism demand statistics 2021 </font>
#
# ## <font color = red >  data information </font>
# - The Second dataset which is about Number of visits for each month and the reasons
#
#
#    you can download dataset : https://data.gov.sa/Data/ar/dataset/the-main-indicators-of-tourism-demand-statistics-2021
#
#
# - The Third dataset which is about Number of visits for each month and regions
#
#   you can download dataset : https://data.gov.sa/Data/ar/dataset/the-main-indicators-of-tourism-demand-statistics-2021

# %% [markdown]
# ### Why we want optimize tourism for tourists?
# ### What we want to understand from this data?
# ### What the most reasons people visiting Saudi Arabia?
# ### Which part of Saudi Arabia do people visit?
# ### What is the best hotels for your budget?

# %% [markdown]
# ## Importing the Packages And Dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
from vega_datasets import data
import seaborn as sns

# %%
df = pd.read_csv("output.csv")
df
# Out:
#       Unnamed: 0                               name  \
# 0              0                    Marina Alsalaam
# 1              1                    Open ApartHotel
# 2              2  العييري للوحدات المفروشة الدمام 4
# 3              3   العييري للوحات المفروشة الدمام 7
# 4              4  Aros Al Faisaliah Furnished Units
# ...          ...                                ...
# 1437          45             Al Aqeeq Madinah Hotel
# 1438          46                     Al Qibla Hotel
# 1439          47                  Dar Al Naem Hotel
# 1440          48              Nozol Royal Inn Hotel
# 1441          49                  فندق رحيق المدينه
#
#                                      location    price          price_for  \
# 0                          Dammam Show on map  SAR 140  1 night, 2 adults
# 1                          Dammam Show on map  SAR 180  1 night, 2 adults
# 2                          Dammam Show on map  SAR 248  1 night, 2 adults
# ...

# %% [markdown]
# ## Exploratory data Analysis (EDA)

# %% [markdown]
# #### display dimensions of data

# %%
df.shape
# Out:
# (1442, 12)

# %% [markdown]
# we have 12 columns and 1442 Row

# %% [markdown]
# #### summary of a Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1442 entries, 0 to 1441
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1442 non-null   int64
#  1   name               1442 non-null   object
#  2   location           1442 non-null   object
#  3   price              1442 non-null   object
#  4   price_for          1442 non-null   object
#  5   room_type          1442 non-null   object
#  6   beds               1434 non-null   object
#  7   rating             1394 non-null   float64
#  8   rating_title       1394 non-null   object
#  9   number_of_ratings  1394 non-null   object
#  10  url                1442 non-null   object
#  11  cm                 257 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 135.3+ KB

# %% [markdown]
# As we can see  summary of  dataset and it show for us  name of each Column and Data type for this colmuns and Count for Non-Null values .

# %% [markdown]
# #### Check missing And Duplicated values .

# %%
df.isnull().sum() # Check missing
# Out:
# Unnamed: 0              0
# name                    0
# location                0
# price                   0
# price_for               0
# room_type               0
# beds                    8
# rating                 48
# rating_title           48
# number_of_ratings      48
# url                     0
# cm                   1185
# dtype: int64

# %% [markdown]
# As we can see we have number of missing data for each column above.

# %%
df.duplicated().sum()
# Out:
# 54

# %% [markdown]
# we have 54 duplicated values.

# %% [markdown]
# ---

# %% [markdown]
# ## <font color = red > Data cleaning </font>

# %%
df = pd.read_csv("output.csv")
print("Before: Data type of Price =", df['price'].dtype)
df['price']=df["price"].str.replace("SAR","")
df['price']=df['price'].str.replace(',','')
df['price']=df['price'].str.strip()
df['price']=pd.to_numeric(df['price'])
print("After: Data type of Price =", df['price'].dtype)
df['price'].dtype
# Out:
# Before: Data type of Price = object
# After: Data type of Price = int64
# dtype('int64')

# %% [markdown]
# #### Deleting the column (  Unnamed: 0 )

# %%
del df['Unnamed: 0'] # deled the column Unnamed: 0 , becous it is unuseful

# %% [markdown]
# #### filling the missing values

# %%
df['cm'].fillna('No cm', inplace = True)

# %%
df['number_of_ratings'].fillna('No reviews', inplace = True)

# %%
df['rating_title'].fillna('No rating title ', inplace = True)   #rating_title

# %%
df['rating'].fillna('0 ', inplace = True) #rating

# %%
df['beds'].fillna('No information ', inplace = True) #beds

# %%
df.isnull().sum()
# Out:
# name                 0
# location             0
# price                0
# price_for            0
# room_type            0
# beds                 0
# rating               0
# rating_title         0
# number_of_ratings    0
# url                  0
# cm                   0
# dtype: int64

# %% [markdown]
# As we can see After we noticed that there are miising values we have replaced them all

# %% [markdown]
# #### duplicated values

# %%
df[df.duplicated()] # find duplicate rows across all columns
# Out:
#                                                   name  \
# 315                            Iwaa Alkharj Apartments
# 316                  Lavana Furnished Apartments Salam
# 317                 Bay La Sun Hotel and Marina - KAEC
# 318                  Vision of Onaizah Furnished Units
# 319                                         Rafa Homes
# 320                                        فندق لافندر
# 321                                  Dar Al Naem Hotel
# 322                          Executives Hotel - Azizia
# 323                                 فندق المحمل العصري
# 324                                      Baylasun Life
# 325                                       Gardens View
# 326                             Hotel Qal'aat AlKhafji
# 327                 Al Muhaidb Residence Al Takhassusi
# 328                                     Al Hayatt Plus
# 329            Al Eairy Furnished Apartments- Jeddah 2
# 330                               اوج للأجنحة الفندقية
# ...

# %% [markdown]
# we dont need to replace any duplicated data becous if we dlete the value at the end it will give us wrong anlalysis

# %% [markdown]
# #### Replacing the names of location

# %%
df['location'].value_counts()
# Out:
# Jeddah Show on map                         190
# Riyadh Show on map                         135
# Dammam Show on map                          99
# Central Madinah, Al Madinah Show on map     77
# Al Salamah, Jeddah Show on map              48
#                                           ...
# Umm as Salām Show on map                     1
# As Sudayrah Show on map                      1
# Half Moon Bay Show on map                    1
# Al Wuhayţ Show on map                        1
# North Obhr, Jeddah Show on map               1
# Name: location, Length: 156, dtype: int64

# %% [markdown]
# As you can see we used value_counts to display how many city that have locations for they'r hotels

# %%
df['location'].unique()
# Out:
# array(['Dammam Show on map', 'Al Muraysīyah Show on map',
#        'Al Olaya, Riyadh Show on map', 'Al Qurayyat Show on map',
#        'Al Hamra, Jeddah Show on map', 'Riyadh Show on map',
#        'Al Wadeen Show on map', 'Al Olayya, Al Khobar Show on map',
#        'Buraydah Show on map', 'Central Madinah, Al Madinah Show on map',
#        'Ţurayf Show on map', 'Al Khobar Show on map',
#        'Makkah Show on map', 'Unayzah Show on map',
#        'Al Worood, Riyadh Show on map', 'Yanbu Show on map',
#        'Jeddah Show on map', 'As Suwayfilah Show on map',
#        'Al Ḩawīyah Show on map', 'Al Malaz, Riyadh Show on map',
#        'Sharurah Show on map', 'Al Khars Show on map',
#        'Tanomah Show on map', 'Khamis Mushayt Show on map',
#        'Az Zulfi Show on map', 'Al Namas Show on map',
#        'Al ‘Awālī Show on map', 'Rafha Show on map', 'Rabigh Show on map',
#        'King Abdullah Economic City Show on map',
# ...

# %%
df['location']= df['location'].replace({'Dammam Show on map': 'Dammam',
                                        'Al Muraysīyah Show on map': 'Makkah',
                                        'Al Olaya, Riyadh Show on map': 'Riyadh',
                                        'Al Qurayyat Show on map': 'Al Qurayyat',
                                         'Al Hamra, Jeddah Show on map': 'Jeddah',
                                         'Riyadh Show on map': 'Riyadh',
                                         'Al Wadeen Show on map': 'Abha',
                                         'Al Olayya, Al Khobar Show on map': 'Al Khobar',
                                         'Buraydah Show on map': 'Buraydah',
                                         'Central Madinah, Al Madinah Show on map': 'Al Madinah',
                                         'Ţurayf Show on map': 'Ţurayf',
                                         'Al Khobar Show on map': 'Al Khobar',
                                         'Makkah Show on map': 'Makkah',
                                         'Unayzah Show on map': 'Unayzah',
                                         'Al Worood, Riyadh Show on map': 'Riyadh',
                                         'Yanbu Show on map': 'Yanbu',
                                         'Jeddah Show on map': 'Jeddah',
                                         'As Suwayfilah Show on map': 'Hail',
                                         'Al Ḩawīyah Show on map': 'Taif',
                                         'Al Malaz, Riyadh Show on map': 'Riyadh',
                                        'Sharurah Show on map': 'Najran',
                                        'Al Khars Show on map': 'Al Ahsaa',
                                        'Tanomah Show on map': 'Tanomah',
                                        'Khamis Mushayt Show on map': 'Khamis Mushayt',
                                        'Az Zulfi Show on map': 'Az Zulfi',
                                        'Al Namas Show on map': 'Al Namas',
                                        'Al ‘Awālī Show on map': 'Makkah',
                                        'Rafha Show on map': 'Rafha',
                                        'Rabigh Show on map': 'Rabigh',
                                        'King Abdullah Economic City Show on map': 'King Abdullah Economic City',
                                        'Riyadh Al Khabra Show on map': 'Riyadh Al Khabra',
                                        'Al Rass Show on map': 'Al Rass',
                                        'Hajlah Show on map': 'Makkah',
                                        'Al Ula Show on map': 'Al Ula',
                                        'Taymāʼ Show on map': 'Tayma',
                                        'Abha Show on map': 'Abha',
                                        'Fayfāʼ Show on map': 'Fayfā',
                                        'Waḩţān Show on map': 'Buraydah',
                                        'Al Lith Show on map': 'Makkah',
                                        'Sīdī Ḩamzah Show on map': 'Al Madinah',
                                        'Qabāʼ Show on map': 'Al Madinah',
                                        'Al Barkah Show on map': 'Al Baha',
                                        'Raghdān Show on map': 'Al Baha',
                                        'Ma‘shī Show on map': 'Makkah',
                                        'Ad Darb Show on map': 'Jizan',
                                        'Bīshat Mushayţ Show on map': 'Khamis Mushayt',
                                        'Al Jāmi‘ah Show on map': 'Jeddah',
                                        'Ad Dawādimī Show on map': 'Al Duwadimi',
                                        'As Sayl aş Şaghīr Show on map': 'Makkah',
                                        'Al Salamah, Jeddah Show on map': 'Jeddah',
                                        'Tabuk Show on map': 'Tabuk',
                                        'Taif Show on map': 'Taif',
                                        'Al Sulimania, Riyadh Show on map': 'Riyadh',
                                        'Al Madinah Show on map': 'Al Madinah',
                                        'Turghush Show on map': 'Asser',
                                        'Hera Street, Jeddah Show on map': 'Jeddah',
                                        '‘Urwah Show on map': 'Al Madinah',
                                        'Ar Riḩāb Show on map': 'Makkah',
                                        'Madain Saleh Show on map': 'Madain Saleh',
                                        'Sari Street, Jeddah Show on map': 'Jeddah',
                                        "Qal'at Bishah Show on map": 'Bishah',
                                        'Al Wuhayţ Show on map': 'Taif',
                                        'As Sudayrah Show on map': 'Makkah',
                                        'Al Fayşalīyah Show on map': 'Dammam',
                                        'Al Jubail Show on map': 'Al Jubail',
                                        'North Obhr, Jeddah Show on map':'Jeddah',
                                        'Al Ḩalaqah Show on map':'Makkah',
                                        'An Nimāş Show on map':'Al Namas',
                                        'Ad Dār as Suflá Show on map':'Riyadh',
                                        'Al Ghāţ Show on map': 'Al Ghāţ',
                                        'Az Zahrāʼ Show on map':'Riyadh',
                                        'Baish Show on map':'Baish',
                                        'Abū Qa‘ar Show on map':'Hafr Al Baten',
                                        'Al Wudayy Show on map':'Al Madinah',
                                        'Al Yarmouk, Al Khobar Show on map':'Al Khobar',
                                        'Al Mikhlaf Show on map':'Najjran',
                                        'Diplomatic Quarter, Riyadh Show on map':'Riyadh',
                                        'Al Hofuf Show on map':'Al Ahsaa',
                                         'Palestine  Street, Jeddah Show on map':'Jeddah',
                                        'Rayyis Show on map':'Jeddah',
                                        'Al Andalus, Jeddah Show on map':'Jeddah',
                                        'King Abdul Aziz Road, Jeddah Show on map':'Jeddah',
                                        'Al Thybiyah Show on map':'Hafr Al Baten',
                                        'Hotat bani tamim Show on map':'Riyadh',
                                        'Ar Ruʼays Show on map':'Jeddah',
                                        'Al Ḩanākīyah Show on map':'Al Madinah',
                                        'Shaban Show on map':'Riyadh',
                                        'Abḩur al Janūbīyah Show on map':'Jeddah',
                                        'Al Qaḑīmah Show on map':'Rabigh',
                                        'Dawmat al Jandal Show on map':'Al Jouf',
                                        'Half Moon Bay Show on map':'Dammam',
                                        'Al Humaizah Show on map':'Riyadh',
                                        'Şabyā Show on map':'Jazan',
                                        'Al Aqrabeyah, Al Khobar Show on map':'Al Khobar',
                                        'Al Khafji Show on map':'Al Khafji',
                                        'Al Shatiea, Jeddah Show on map':'Jeddah',
                                        'Buraymān Show on map':'Jeddah',
                                        'Wadi Al Dawasir Show on map':'Riyadh',
                                        'Durat  Alarous Show on map':'Jeddah',
                                        'Ar Rafī‘ah Show on map':'Riyadh',
                                        'Al Ahsa Show on map':'Al Ahsaa',
                                        'Sawdāʼ Show on map':'Abha',
                                        'Al Baha Show on map':'Al Baha',
                                        'An Nikāshah Show on map':'Makkah',
                                        'Al Hamra, Riyadh Show on map':'Riyadh',
                                        'Ash Shiqqah Show on map':'Buraydah',
                                        'Al Nairyah Show on map':'Al Nairyah',
                                        'Baljurashi Show on map':'Al Baha',
                                        'Ash Shuqayq Show on map':'Jizan',
                                        'Al Aqiq Show on map':'Riyadh',
                                        'Qaryah al ‘Ulyā Show on map':'Qaryah al Ulyā',
                                        'Sulţānah Show on map':'Al Madinah',
                                        'Raʼs Munaysif Show on map':'Al Khobar',
                                        'Hafr Al Baten Show on map':'Hafr Al Baten',
                                        'Arar Show on map':'Arar',
                                        'Al Hada Show on map':'Taif',
                                        'Umm Lajj Show on map':'Umm Lajj',
                                        '‘Afīf Show on map':'Afīf',
                                        'South Obhr, Jeddah Show on map':'Jeddah',
                                        'Ajyad, Makkah Show on map':'Makkah',
                                        'Al Bukayriyah Show on map':'Bukayriyah',
                                        'Laylá Show on map':'Riyadh',
                                        'Şadyān Show on map':'Hail',
                                        'An Nuqrah Show on map':'Hail',
                                        'Al Aziziyah, Makkah Show on map':'Makkah',
                                        'Al Tahlia Street, Jeddah Show on map':'Jeddah',
                                        'Al Qunfudhah Show on map':'Al Qunfudhah',
                                        'Ahad Rafidah Show on map':'Asser',
                                        'Al Madārah Show on map':'Riyadh',
                                        'Al Wahţ Show on map':'Makkah',
                                        'Hail Show on map':'Hail',
                                        'Sabt Alalayah Show on map':'Asser',
                                        'Sakakah Show on map':'Sakakah',
                                        'Al Muwayh Show on map':'Makkah',
                                        'Şulbūkh Show on map':'Riyadh',
                                        'Raʼs al Khafjī Show on map':'Al Khafji',
                                        'Jazan Show on map':'Jazan',
                                        'Al Kharj Show on map':'Al Kharj',
                                        'Al Aziziyah, Riyadh Show on map':'Riyadh',
                                        'Najran Show on map':'Najran',
                                        'Al Ḩillah Show on map':'Riyadh',
                                        'Al Muzāḩimīyah Show on map':'Riyadh',
                                        'Al Khabrāʼ Show on map':'Qassim',
                                        'Ash Shuwaybiţ Show on map':'Makkah',
                                        'Shaqra Show on map':'Shaqra',
                                        'Al Rawda, Jeddah Show on map':'Jeddah',
                                        'Ḩaraḑ Show on map':'Al Ahsaa',
                                        'Qurish Street, Jeddah Show on map':'Jeddah',
                                        'Ilbaras Show on map':'Buraydah',
                                        'Bin Hashbal Show on map':'Khamis Mushayt',
                                        'Al ‘Azīzīyah Show on map':'Makkah',
                                        'Khumrah Show on map':'Makkah',
                                        'Umm as Salām Show on map':'Jazan',
                                        'Obhor Show on map':'Jeddah',
                                        'Al Kāmil Show on map':'Makkah',
                                        'Şāmitah Show on map':'Jazan',
                                        'An Nimāş':'Al Namas'
                                       
})

# %% [markdown]
# As you can see we want to reduce the streets villages and residentail neighborhoods to but them under the cites names

# %%
df['location'].value_counts()
# Out:
# Jeddah                         380
# Riyadh                         216
# Al Madinah                     138
# Makkah                         119
# Dammam                         104
# Al Khobar                       52
# Taif                            51
# Abha                            37
# Buraydah                        25
# Jazan                           22
# Yanbu                           22
# Khamis Mushayt                  20
# Hail                            20
# Najran                          17
# Al Jubail                       17
# King Abdullah Economic City     15
# Al Ula                          15
# Rabigh                          13
# Unayzah                         12
# Ţurayf                          12
# Tabuk                           10
# Hafr Al Baten                   10
# Asser                            9
# Al Rass                          7
# Al Namas                         7
# Al Kharj                         6
# Al Baha                          6
# ...

# %%
df['location'].unique()
# Out:
# array(['Dammam', 'Makkah', 'Riyadh', 'Al Qurayyat', 'Jeddah', 'Abha',
#        'Al Khobar', 'Buraydah', 'Al Madinah', 'Ţurayf', 'Unayzah',
#        'Yanbu', 'Hail', 'Taif', 'Najran', 'Al Ahsaa', 'Tanomah',
#        'Khamis Mushayt', 'Az Zulfi', 'Al Namas', 'Rafha', 'Rabigh',
#        'King Abdullah Economic City', 'Riyadh Al Khabra', 'Al Rass',
#        'Al Ula', 'Tayma', 'Fayfā', 'Al Baha', 'Jizan', 'Al Duwadimi',
#        'Tabuk', 'Asser', 'Madain Saleh', 'Bishah', 'Al Jubail', 'Jazan',
#        'Shaqra', 'Qassim', 'Al Kharj', 'Al Khafji', 'Sakakah',
#        'Al Qunfudhah', 'Bukayriyah', 'Afīf', 'Umm Lajj', 'Hafr Al Baten',
#        'Arar', 'Qaryah al Ulyā', 'Al Nairyah', 'Al Jouf', 'Najjran',
#        'Baish', 'Al Ghāţ'], dtype=object)

# %% [markdown]
# As you can see we have reduced the streets villages and residentail neighborhoods to but them under the cites names

# %%
Regions = {'Eastren_Province':['Dammam','Al Khobar','Al Ahsaa','Al Jubail','Al Khafji','Hafr Al Baten','Qaryah al ‘Ulyā','Al Nairyah','Qaryah al Ulyā'],
                              'Riyadh_Province':['Az Zulfi','Al Duwadimi','Shaqra','Al Kharj','Afīf','Al Ghāţ','Riyadh'],
           'Makkah_Province':['Makkah','Jeddah','King Abdullah Economic City','Taif','Rabigh','Al Qunfudhah'],
           'Al Madinah_Province':['Al Madinah','Yanbu','Al Ula','Madain Saleh','Madinah'],
           'Qassim_Province':['Buraydah','Unayzah','Al Rass','Qassim','Bukayriyah','Riyadh Al Khabra'],
           'Tabuk_Province':['Tabuk','Umm Lajj','Tayma'],
           'Al Jouf_Province':['Al Jouf','Al Qurayyat','Sakakah'],
           'Hail_Province':['Hail'],
           'Northern Borders_Province':['Ţurayf','Arar','Rafha'],
           'Asser_Province':['Khamis Mushayt','Al Namas','Tanomah','Abha','Baish','Bishah','Asser'],
           'Al Baha_Province':['Al Baha','Al Namas','Tanomah'],
           'Najjran_Province':['Najjran','Najran'],
           'Jizan_Province':['Jizan','Jazan','Fayfā']}

# %% [markdown]
# As you can see we assign each cities to the region

# %%
def get_key(val):
    for key, value in Regions.items():
        for v in value:
            if val == v:
                return key
    return "key doesn't exist"

# %% [markdown]
# As you can see the function take each city and put it into the region belong to

# %%
df["Region"] = df["location"].apply(get_key)

# %% [markdown]
# As you can see we used this code to apply the function for the location column

# %%
df
# Out:
#                                    name    location  price          price_for  \
# 0                       Marina Alsalaam      Dammam    140  1 night, 2 adults
# 1                       Open ApartHotel      Dammam    180  1 night, 2 adults
# 2     العييري للوحدات المفروشة الدمام 4      Dammam    248  1 night, 2 adults
# 3      العييري للوحات المفروشة الدمام 7      Dammam    250  1 night, 2 adults
# 4     Aros Al Faisaliah Furnished Units      Dammam    224  1 night, 2 adults
# ...                                 ...         ...    ...                ...
# 1437             Al Aqeeq Madinah Hotel  Al Madinah    285  1 night, 2 adults
# 1438                     Al Qibla Hotel  Al Madinah    209  1 night, 2 adults
# 1439                  Dar Al Naem Hotel  Al Madinah    150  1 night, 2 adults
# 1440              Nozol Royal Inn Hotel  Al Madinah    189  1 night, 2 adults
# 1441                  فندق رحيق المدينه  Al Madinah     81  1 night, 2 adults
#
# ...

# %% [markdown]
# In the code above we have put each city in its province

# %%
del df['url'] # deleting the column named because it's not usefule

# %% [markdown]
# -------

# %%
sd=df[['location','Region']]#Making sure that the cities connected to their regions
sd
# Out:
#         location               Region
# 0         Dammam     Eastren_Province
# 1         Dammam     Eastren_Province
# 2         Dammam     Eastren_Province
# 3         Dammam     Eastren_Province
# 4         Dammam     Eastren_Province
# ...          ...                  ...
# 1437  Al Madinah  Al Madinah_Province
# 1438  Al Madinah  Al Madinah_Province
# 1439  Al Madinah  Al Madinah_Province
# 1440  Al Madinah  Al Madinah_Province
# 1441  Al Madinah  Al Madinah_Province
#
# [1442 rows x 2 columns]

# %% [markdown]
# #### This data  (Tourism Demand Indcators in the Kingdom of Saudi Arabia 2021) from open saudi data
# ##### Abuot  Domestic Tourist Trips by Main Purpose (1000 Trips)

# %%
to = pd.read_excel('tourism2021.xlsx', sheet_name='D2')
to
# Out:
#    (Last update: 10-04-2022)  \
# 0                        NaN
# 1                         D2
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
#
#                                            Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN
# 1   Domestic Tourist Trips by Main Purpose ('000 T...        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN      Month
# 4                                                2021    January
# ...

# %% [markdown]
# filling the missing values in the column named(Unnamed: 2)

# %%
to['Unnamed: 2'] = to['Unnamed: 2'].fillna('Total')
to
# Out:
#    (Last update: 10-04-2022)  \
# 0                        NaN
# 1                         D2
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
#
#                                            Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN      Total
# 1   Domestic Tourist Trips by Main Purpose ('000 T...      Total
# 2                                                 NaN      Total
# 3                                                 NaN      Month
# 4                                                2021    January
# ...

# %% [markdown]
# As you can see we used fillna to fill missing value

# %%
del to['(Last update: 10-04-2022)']

# %%
del to['Unnamed: 10']

# %%
del to['Unnamed: 9']

# %%
del to['Unnamed: 1']

# %% [markdown]
# ### We delete the coulmns that unuseful for us

# %%
to
# Out:
#    Unnamed: 2              Unnamed: 3                    Unnamed: 4  \
# 0       Total                     NaN                           NaN
# 1       Total                     NaN                           NaN
# 2       Total                     NaN                           NaN
# 3       Month  Religious\nأغراض دينية  Business\nالأعمال والمؤتمرات
# 4     January                1221.308                       279.012
# 5    February                  651.48                       178.255
# 6       March                 397.796                       166.062
# 7       April                 876.049                       191.283
# 8         May                 466.484                        191.41
# 9        June                 505.219                       222.698
# 10       July                 503.252                       121.091
# 11     August                 441.326                       203.148
# 12  September                 509.635                       150.993
# ...

# %% [markdown]
# we have a duplicated columns in both Arabic and English so we just want to keep the English columns

# %%
to = to.drop([0, 1, 2, 3, 14, 15, 16])

# %%
to
# Out:
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 4     January   1221.308    279.012   2753.817    148.659   1452.715
# 5    February     651.48    178.255   2688.574    107.859   1821.958
# 6       March    397.796    166.062   2040.071     89.359   1675.717
# 7       April    876.049    191.283   1919.078     96.022   1313.591
# 8         May    466.484     191.41   2024.054     64.337   1327.952
# 9        June    505.219    222.698   3406.026    121.349   2285.974
# 10       July    503.252    121.091    2634.15     86.749   3447.868
# 11     August    441.326    203.148   3170.036     84.429   1622.855
# 12  September    509.635    150.993   1904.721     100.08   1833.926
# 13    October    488.468    228.789   2534.441    165.504   1537.577
#
#    Unnamed: 8
# 4    5855.511
# 5    5448.126
# 6    4369.004
# 7    4396.024
# 8    4074.237
# 9    6541.266
# 10   6793.111
# 11   5521.794
# 12   4499.355
# 13    4954.78

# %%
to1 = to.reset_index()

# %%
to1
# Out:
#    index Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0      4    January   1221.308    279.012   2753.817    148.659   1452.715
# 1      5   February     651.48    178.255   2688.574    107.859   1821.958
# 2      6      March    397.796    166.062   2040.071     89.359   1675.717
# 3      7      April    876.049    191.283   1919.078     96.022   1313.591
# 4      8        May    466.484     191.41   2024.054     64.337   1327.952
# 5      9       June    505.219    222.698   3406.026    121.349   2285.974
# 6     10       July    503.252    121.091    2634.15     86.749   3447.868
# 7     11     August    441.326    203.148   3170.036     84.429   1622.855
# 8     12  September    509.635    150.993   1904.721     100.08   1833.926
# 9     13    October    488.468    228.789   2534.441    165.504   1537.577
#
#   Unnamed: 8
# 0   5855.511
# 1   5448.126
# 2   4369.004
# 3   4396.024
# 4   4074.237
# 5   6541.266
# 6   6793.111
# 7   5521.794
# ...

# %% [markdown]
# Here we have two index the old one and the new one so we just want to keep the new one and delete the old

# %%
del to1['index']

# %%
to1
# Out:
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0    January   1221.308    279.012   2753.817    148.659   1452.715   5855.511
# 1   February     651.48    178.255   2688.574    107.859   1821.958   5448.126
# 2      March    397.796    166.062   2040.071     89.359   1675.717   4369.004
# 3      April    876.049    191.283   1919.078     96.022   1313.591   4396.024
# 4        May    466.484     191.41   2024.054     64.337   1327.952   4074.237
# 5       June    505.219    222.698   3406.026    121.349   2285.974   6541.266
# 6       July    503.252    121.091    2634.15     86.749   3447.868   6793.111
# 7     August    441.326    203.148   3170.036     84.429   1622.855   5521.794
# 8  September    509.635    150.993   1904.721     100.08   1833.926   4499.355
# 9    October    488.468    228.789   2534.441    165.504   1537.577    4954.78

# %%
to = to1

# %%
to
# Out:
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0    January   1221.308    279.012   2753.817    148.659   1452.715   5855.511
# 1   February     651.48    178.255   2688.574    107.859   1821.958   5448.126
# 2      March    397.796    166.062   2040.071     89.359   1675.717   4369.004
# 3      April    876.049    191.283   1919.078     96.022   1313.591   4396.024
# 4        May    466.484     191.41   2024.054     64.337   1327.952   4074.237
# 5       June    505.219    222.698   3406.026    121.349   2285.974   6541.266
# 6       July    503.252    121.091    2634.15     86.749   3447.868   6793.111
# 7     August    441.326    203.148   3170.036     84.429   1622.855   5521.794
# 8  September    509.635    150.993   1904.721     100.08   1833.926   4499.355
# 9    October    488.468    228.789   2534.441    165.504   1537.577    4954.78

# %% [markdown]
# Renaming the columns names

# %%
to.rename(columns = {'Unnamed: 2':'Months',
                     'Unnamed: 3':'Religious',
                     'Unnamed: 4':'Business',
                     'Unnamed: 5':'Leisure',
                     'Unnamed: 6':'Other',
                     'Unnamed: 7':'Family visits',
                     'Unnamed: 8':'Total'}, inplace = True)

# %% [markdown]
# As you can see we renamed the columns name

# %%
to['Religious']=pd.to_numeric(to['Religious'])
to['Business']=pd.to_numeric(to['Business'])
to['Leisure']=pd.to_numeric(to['Leisure'])
to['Other']=pd.to_numeric(to['Other'])
to['Family visits']=pd.to_numeric(to['Family visits'])
to['Total']=pd.to_numeric(to['Total'])

# %% [markdown]
# As you can see we changed the type for each column to numeric ' int , float ' values type

# %%
to.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Months         10 non-null     object
#  1   Religious      10 non-null     float64
#  2   Business       10 non-null     float64
#  3   Leisure        10 non-null     float64
#  4   Other          10 non-null     float64
#  5   Family visits  10 non-null     float64
#  6   Total          10 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 688.0+ bytes

# %%
to
# Out:
#       Months  Religious  Business   Leisure    Other  Family visits     Total
# 0    January   1221.308   279.012  2753.817  148.659       1452.715  5855.511
# 1   February    651.480   178.255  2688.574  107.859       1821.958  5448.126
# 2      March    397.796   166.062  2040.071   89.359       1675.717  4369.004
# 3      April    876.049   191.283  1919.078   96.022       1313.591  4396.024
# 4        May    466.484   191.410  2024.054   64.337       1327.952  4074.237
# 5       June    505.219   222.698  3406.026  121.349       2285.974  6541.266
# 6       July    503.252   121.091  2634.150   86.749       3447.868  6793.111
# 7     August    441.326   203.148  3170.036   84.429       1622.855  5521.794
# 8  September    509.635   150.993  1904.721  100.080       1833.926  4499.355
# 9    October    488.468   228.789  2534.441  165.504       1537.577  4954.780

# %% [markdown]
# #### <font color = red >  You can see above this is data after cleaning you can see that in this data number of Domestic Tourist Trips by Main Purpose (1000 Trips) </font>

# %%
su = to.sum(axis = 0, skipna = True)
su
# Out:
# Months           JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...
# Religious                                                 6061.017
# Business                                                  1932.741
# Leisure                                                  25074.968
# Other                                                     1064.347
# Family visits                                            18320.133
# Total                                                    52453.208
# dtype: object

# %%
sm = pd.DataFrame(to.sum())
sm
# Out:
#                                                                0
# Months         JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...
# Religious                                               6061.017
# Business                                                1932.741
# Leisure                                                25074.968
# Other                                                   1064.347
# Family visits                                          18320.133
# Total                                                  52453.208

# %% [markdown]
# #### This is Sum for each column, and we can see that max reason for visiting the saudi arabia is Leisure

# %% [markdown]
# ----

# %% [markdown]
# #### This data  (Tourism Demand Indcators in the Kingdom of Saudi Arabia 2021) from open saudi data
# ##### Abuot  Domestic Tourist Trips by Origin- Province (1000 Trips)

# %%
d3 = pd.read_excel('tourism2021.xlsx', sheet_name='D3')
d3
# Out:
#    (Last update: 10-04-2022)  \
# 0                        NaN
# 1                         D3
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                 NaN        NaN        NaN
# 1   Domestic Tourist Trips by Origin- Province ('0...        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN        NaN     الباحة
# ...

# %%
ty = d3.drop([0, 1, 2, 3, 4, 15, 16,17])
ty
# Out:
#    (Last update: 10-04-2022) Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 5                        NaN       2021    January    264.015    756.238
# 6                        NaN        NaN   February    113.609    523.064
# 7                        NaN        NaN      March     86.258    463.423
# 8                        NaN        NaN      April     71.834     812.54
# 9                        NaN        NaN        May     73.041    676.667
# 10                       NaN        NaN       June    122.361    889.602
# 11                       NaN        NaN       July        167    452.525
# 12                       NaN        NaN     August    114.739    339.534
# 13                       NaN        NaN  September     71.505    461.164
# 14                       NaN        NaN    October     81.453    546.797
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 5     429.119     491.74    538.777    400.032    214.385      231.42
# ...

# %%
del ty['(Last update: 10-04-2022)']

# %%
del ty['Unnamed: 1']

# %%
del ty['Unnamed: 17']

# %%
del ty['Unnamed: 18']

# %%
ty
# Out:
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 5     January    264.015    756.238    429.119     491.74    538.777
# 6    February    113.609    523.064    370.952    442.904    488.404
# 7       March     86.258    463.423    254.748     393.76    351.713
# 8       April     71.834     812.54    722.823    395.034     287.79
# 9         May     73.041    676.667     473.82    253.874    133.454
# 10       June    122.361    889.602     606.83    506.775    297.404
# 11       July        167    452.525    544.259    891.208    157.115
# 12     August    114.739    339.534    441.929    881.192    146.787
# 13  September     71.505    461.164    258.988    522.893     145.32
# 14    October     81.453    546.797    306.128    651.335    167.187
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 5     400.032    214.385      231.42    1065.655      52.734     123.872
# ...

# %% [markdown]
# Renaming the columns names

# %%
ty.rename(columns = {'Unnamed: 2':'Months',
                     'Unnamed: 3':'Albaha',
                     'Unnamed: 4':'Alqassim',
                     'Unnamed: 5':'Aseer',
                     'Unnamed: 6':'Eastern',
                     'Unnamed: 7':'Hail',
                     'Unnamed: 8':'Jazan',
                     'Unnamed: 9':'Jouf',
                     'Unnamed: 10':'Madinah',
                     'Unnamed: 11':'Makkah',
                     'Unnamed: 12':'Najran',
                     'Unnamed: 13':'Northern Borders',
                     'Unnamed: 14':'Riyadh',
                     'Unnamed: 15':'Tabuk',
                     'Unnamed: 16':'Total' }, inplace = True)
ty
# Out:
#        Months   Albaha Alqassim    Aseer  Eastern     Hail    Jazan     Jouf  \
# 5     January  264.015  756.238  429.119   491.74  538.777  400.032  214.385
# 6    February  113.609  523.064  370.952  442.904  488.404  405.705  219.681
# 7       March   86.258  463.423  254.748   393.76  351.713   327.55  143.964
# 8       April   71.834   812.54  722.823  395.034   287.79   296.37   82.844
# 9         May   73.041  676.667   473.82  253.874  133.454   413.23   42.972
# 10       June  122.361  889.602   606.83  506.775  297.404  808.148   82.391
# 11       July      167  452.525  544.259  891.208  157.115   297.19   82.333
# 12     August  114.739  339.534  441.929  881.192  146.787   315.99  127.156
# 13  September   71.505  461.164  258.988  522.893   145.32  364.234   68.022
# 14    October   81.453  546.797  306.128  651.335  167.187  330.031   67.242
#
#     Madinah    Makkah   Najran Northern Borders    Riyadh    Tabuk     Total
# ...

# %%
ry= ty.reset_index()
ry
# Out:
#    index     Months   Albaha Alqassim    Aseer  Eastern     Hail    Jazan  \
# 0      5    January  264.015  756.238  429.119   491.74  538.777  400.032
# 1      6   February  113.609  523.064  370.952  442.904  488.404  405.705
# 2      7      March   86.258  463.423  254.748   393.76  351.713   327.55
# 3      8      April   71.834   812.54  722.823  395.034   287.79   296.37
# 4      9        May   73.041  676.667   473.82  253.874  133.454   413.23
# 5     10       June  122.361  889.602   606.83  506.775  297.404  808.148
# 6     11       July      167  452.525  544.259  891.208  157.115   297.19
# 7     12     August  114.739  339.534  441.929  881.192  146.787   315.99
# 8     13  September   71.505  461.164  258.988  522.893   145.32  364.234
# 9     14    October   81.453  546.797  306.128  651.335  167.187  330.031
#
#       Jouf  Madinah    Makkah   Najran Northern Borders    Riyadh    Tabuk  \
# 0  214.385   231.42  1065.655   52.734          123.872  1043.185  244.339
# ...

# %% [markdown]
# Here we have two index the old one and the new one so we just want to keep the new one and delete the old

# %%
del ry['index']

# %%
ry['Albaha']=pd.to_numeric(ry['Albaha'])
ry['Alqassim']=pd.to_numeric(ry['Alqassim'])
ry['Aseer']=pd.to_numeric(ry['Aseer'])
ry['Eastern']=pd.to_numeric(ry['Eastern'])
ry['Hail']=pd.to_numeric(ry['Hail'])
ry['Jazan']=pd.to_numeric(ry['Jazan'])
ry['Jouf']=pd.to_numeric(ry['Jouf'])
ry['Madinah']=pd.to_numeric(ry['Madinah'])
ry['Makkah']=pd.to_numeric(ry['Makkah'])
ry['Najran']=pd.to_numeric(ry['Najran'])
ry['Northern Borders']=pd.to_numeric(ry['Northern Borders'])
ry['Riyadh']=pd.to_numeric(ry['Riyadh'])
ry['Tabuk']=pd.to_numeric(ry['Tabuk'])
ry['Total']=pd.to_numeric(ry['Total'])

# %%
ry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Months            10 non-null     object
#  1   Albaha            10 non-null     float64
#  2   Alqassim          10 non-null     float64
#  3   Aseer             10 non-null     float64
#  4   Eastern           10 non-null     float64
#  5   Hail              10 non-null     float64
#  6   Jazan             10 non-null     float64
#  7   Jouf              10 non-null     float64
#  8   Madinah           10 non-null     float64
#  9   Makkah            10 non-null     float64
#  10  Najran            10 non-null     float64
#  11  Northern Borders  10 non-null     float64
#  12  Riyadh            10 non-null     float64
#  13  Tabuk             10 non-null     float64
#  14  Total             10 non-null     float64
# dtypes: float64(14), object(1)
# memory usage: 1.3+ KB

# %%
ty = ry
ty
# Out:
#       Months   Albaha  Alqassim    Aseer  Eastern     Hail    Jazan     Jouf  \
# 0    January  264.015   756.238  429.119  491.740  538.777  400.032  214.385
# 1   February  113.609   523.064  370.952  442.904  488.404  405.705  219.681
# 2      March   86.258   463.423  254.748  393.760  351.713  327.550  143.964
# 3      April   71.834   812.540  722.823  395.034  287.790  296.370   82.844
# 4        May   73.041   676.667  473.820  253.874  133.454  413.230   42.972
# 5       June  122.361   889.602  606.830  506.775  297.404  808.148   82.391
# 6       July  167.000   452.525  544.259  891.208  157.115  297.190   82.333
# 7     August  114.739   339.534  441.929  881.192  146.787  315.990  127.156
# 8  September   71.505   461.164  258.988  522.893  145.320  364.234   68.022
# 9    October   81.453   546.797  306.128  651.335  167.187  330.031   67.242
#
#    Madinah    Makkah   Najran  Northern Borders    Riyadh    Tabuk     Total
# ...

# %% [markdown]
# #### <font color = red >  You can see above thisis data after cleaning you can see that in this data number of Domestic Tourist Trips by Origin- Province (1000 Trips) </font>

# %%
sw = pd.DataFrame(ty.sum())
sw
# Out:
#                                                                   0
# Months            JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...
# Albaha                                                     1165.815
# Alqassim                                                   5921.554
# Aseer                                                      4409.596
# Eastern                                                    5430.715
# Hail                                                       2713.951
# Jazan                                                       3958.48
# Jouf                                                        1130.99
# Madinah                                                    1192.232
# Makkah                                                    11935.496
# Najran                                                      703.047
# Northern Borders                                            638.101
# Riyadh                                                    10939.778
# ...

# %% [markdown]
# #### This is Sum for each column and we can see that max regions for visiting the saudi arabia is Makkah

# %% [markdown]
# ___

# %% [markdown]
# ### <font color = red > visualization </font>

# %%
 ch1 = alt.Chart(df).mark_bar().encode( 

    x=alt.X('Region'), 
    y='sum(price)', 
    color='Region',
    tooltip = 'Region'
)
  

 m1 = alt.Chart(df).mark_bar().encode( 

    x=alt.X('Region'), 
    y='mean(price)', 
    color='Region',
     tooltip = 'Region'
)
b1 =   alt.Chart(df).mark_bar().encode( 

    x=alt.X('Region'), 
    y='price', 
    color='Region',
    tooltip = 'Region'
)    
    
ch1 | m1 |b1
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# - As you can see the sum of the highest prices was for Makkah province
# - As you can see the highest average for price was in Riyadh province
# - As you can see the most higher hotels price was for Eastren province

# %%
re1 = alt.Chart(df[ df["Region"]=="Makkah_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Makkah Province  "),
    color='location',
     tooltip = 'location'
   
) 

re2 = alt.Chart(df[ df["Region"]=="Al Madinah_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Al Madinah Province  "),
    color='location',
     tooltip = 'location'
   
) 
re3 = alt.Chart(df[ df["Region"]=="Eastren_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Eastren Province  "),
    color='location',
     tooltip = 'location'
   
)
re4 = alt.Chart(df[ df["Region"]=="Riyadh_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Riyadh Province  "),
    color='location',
     tooltip = 'location'
   
)
re5 = alt.Chart(df[ df["Region"]=="Al Jouf_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Al Jouf Province  "),
    color='location',
     tooltip = 'location'
   
)
re6 = alt.Chart(df[ df["Region"]=="Asser_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Asser Province  "),
    color='location',
     tooltip = 'location'
   
)
re7 = alt.Chart(df[ df["Region"]=="Qassim_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Qassim Province  "),
    color='location',
     tooltip = 'location'
   
)
re8 = alt.Chart(df[ df["Region"]=="Northern Borders_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Northern Borders Province  "),
    color='location',
     tooltip = 'location'
   
)
re9 = alt.Chart(df[ df["Region"]=="Hail_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Hail Province  "),
    color='location',
     tooltip = 'location'
   
)
re10 = alt.Chart(df[ df["Region"]=="Najjran_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Najjran Province  "),
    color='location',
     tooltip = 'location'
   
)
re11 = alt.Chart(df[ df["Region"]=="Tabuk_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Tabuk Province  "),
    color='location',
     tooltip = 'location'
   
)
re12 = alt.Chart(df[ df["Region"]=="Jizan_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Jizan Province  "),
    color='location',
     tooltip = 'location'
   
)
re13 = alt.Chart(df[ df["Region"]=="Al Baha_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("sum(price)", title=" The sum of prices for Al Baha Province  "),
    color='location',
     tooltip = 'location'
   
)

re1|re2|re3|re4|re5|re6|re7|re8|re9|re10|re11|re12|re13
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ####  Here we can see the sum of prices for each cities in the province
# - In Makkah province Jeddah was the higher city that people come to and spend there money
# - In Al Madinah province Al Madinah city was the higher city that people come to and spend there money
# - In Eastren province Dammam and Al Khobar was the higher city that people come to and spend there money
# - In Riyadh province Riyadh was the higher city that people come to and spend there money
# - In Al Jouf province Sakakah and Al Jouf was the higher city that people come to and spend there money
# - In Asser province Abha was the higher city that people come to and spend there money
# - In Qassim province Buraydah was the higher city that people come to and spend there money
# - In Broders province Turayf was the higher city that people come to and spend there money
# - In Hail province Hail was the higher city that people come to and spend there money
# - In Najjran province Najjran was the higher city that people come to and spend there money
# - In Tabuk province Umm Lajj and Tabuk was the higher city that people come to and spend there money
# - In Jizan province Jazan was the higher city that people come to and spend there money
# - In Al Baha province Al Baha was the higher city that people come to and spend there money

# %%
rem1 = alt.Chart(df[ df["Region"]=="Makkah_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Makkah Province  "),
    color='location',
    tooltip = 'location'
   
) 

rem2 = alt.Chart(df[ df["Region"]=="Al Madinah_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Al Madinah Province  "),
    color='location',
    tooltip = 'location'
   
) 
rem3 = alt.Chart(df[ df["Region"]=="Eastren_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Eastren Province  "),
    color='location',
    tooltip = 'location'
   
)
rem4 = alt.Chart(df[ df["Region"]=="Riyadh_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Riyadh Province  "),
    color='location',
    tooltip = 'location'
   
)
rem5 = alt.Chart(df[ df["Region"]=="Al Jouf_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Al Jouf Province  "),
    color='location',
    tooltip = 'location'
   
)
rem6 = alt.Chart(df[ df["Region"]=="Asser_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Asser Province  "),
    color='location',
    tooltip = 'location'
   
)
rem7 = alt.Chart(df[ df["Region"]=="Qassim_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Qassim Province  "),
    color='location',
    tooltip = 'location'
   
)
rem8 = alt.Chart(df[ df["Region"]=="Northern Borders_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Northern Borders Province  "),
    color='location',
    tooltip = 'location'
   
)
rem9 = alt.Chart(df[ df["Region"]=="Hail_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Hail Province  "),
    color='location',
    tooltip = 'location'
   
)
rem10 = alt.Chart(df[ df["Region"]=="Najjran_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Najjran Province  "),
    color='location',
    tooltip = 'location'
   
)
rem11 = alt.Chart(df[ df["Region"]=="Tabuk_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Tabuk Province  "),
    color='location',
    tooltip = 'location'
   
)
rem12 = alt.Chart(df[ df["Region"]=="Jizan_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Jizan Province  "),
    color='location',
    tooltip = 'location'
   
)
rem13 = alt.Chart(df[ df["Region"]=="Al Baha_Province"  ]).mark_bar().encode(
   x = alt.X("location"), 
   y = alt.Y("mean(price)", title=" The mean of prices for Al Baha Province  "),
    color='location',
    tooltip = 'location'
   
)

rem1|rem2|rem3|rem4|rem5|rem6|rem7|rem8|rem9|rem10|rem11|rem12|rem13
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ####  Here we can see the mean of prices for each cities in the province
# - In the Makkah region, the city of King Abdullah Economic City got an average price of 900 riyals
# - In the Al Madinah region, the city of Madain Saleh got an average price of 1600 riyals
# - In the Eastern region, the city of Al Khobar got an average price of 500 riyals
# - In the Ryiadh region, the city of Riyadh got an average price of 400 riyals
# - In the Al Jouf region, the city of Al Qurayyat got an average price of 200 riyals
# - In the Asser region, the city of Bishah got an average price of 330 riyals
# - In the Al Qassim region, the city of Buraydah got an average price of 330 riyals
# - In the Northem borders region, the city of Turayf got an average price of 160 riyals
# - In the Hail region, the city of Hail got an average price of 230 riyals
# - In the Najjran region, the city of Najjran got an average price of 200 riyals
# - In the Tabuk region, the city of Umm Lajj got an average price of 470 riyals
# - In the Jizan region, the city of Fayfa got an average price of 650 riyals
# - In the Al Baha region, the city of Al Baha got an average price of 300 riyals

# %%
n1 = alt.Chart(df).mark_text().encode(
    x = 'sum(price)',
    y = 'Region',
    size = 'Region',
    color = 'Region',
    text = 'Region',
    tooltip = ['Region','sum(price):N']
)
n2 =  alt.Chart(df).mark_text().encode(
    x = 'mean(price)',
    y = 'Region',
    size = 'Region',
    color = 'Region',
    text = 'Region',
    tooltip = ['Region','mean(price):N']
)
n1|n2
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# - We see here Makkah province is most province that people spend money
# - We see here Ryiadh province is the highest average between the regions

# %%
alt.Chart(df[ df["location"]=="Riyadh"  ]).transform_calculate(
    
).mark_point().encode(
    x='rating:Q',
    y='price:Q',
    color='name:N',
    tooltip=['name:N', 'rating:N','price:N']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# As you can see the name and price and raitng for each hotels in Riyadh city

# %%
to
# Out:
#       Months  Religious  Business   Leisure    Other  Family visits     Total
# 0    January   1221.308   279.012  2753.817  148.659       1452.715  5855.511
# 1   February    651.480   178.255  2688.574  107.859       1821.958  5448.126
# 2      March    397.796   166.062  2040.071   89.359       1675.717  4369.004
# 3      April    876.049   191.283  1919.078   96.022       1313.591  4396.024
# 4        May    466.484   191.410  2024.054   64.337       1327.952  4074.237
# 5       June    505.219   222.698  3406.026  121.349       2285.974  6541.266
# 6       July    503.252   121.091  2634.150   86.749       3447.868  6793.111
# 7     August    441.326   203.148  3170.036   84.429       1622.855  5521.794
# 8  September    509.635   150.993  1904.721  100.080       1833.926  4499.355
# 9    October    488.468   228.789  2534.441  165.504       1537.577  4954.780

# %%
l1=alt.Chart(to).mark_line().encode(x='Months', y='Religious',tooltip=[
        alt.Tooltip('Months:O', title='Months'),
        alt.Tooltip('Religious:Q', title='Religious') ]).properties( width=500,height=500)

l2=alt.Chart(to).mark_line(color='red').encode(x='Months', y='Business',tooltip=[
        alt.Tooltip('Months:O', title='Months'),
        alt.Tooltip('Business:Q', title='Business') ]).properties( width=500,height=500)

l3=alt.Chart(to).mark_line(color='Orange').encode(x='Months', y='Leisure',tooltip=[
        alt.Tooltip('Months:O', title='Months'),
        alt.Tooltip('Leisure:Q', title='Leisure') ]).properties( width=500,height=500)

l4=alt.Chart(to).mark_line(color='MediumSpringGreen').encode(x='Months', y='Other',tooltip=[
        alt.Tooltip('Months:O', title='Months'),
        alt.Tooltip('Other:Q', title='Other') ]).properties( width=500,height=500)

l5=alt.Chart(to).mark_line(color='Purple').encode(x='Months', y='Family visits',tooltip=[
        alt.Tooltip('Months:O', title='Months'),
        alt.Tooltip('Family visits:Q', title='Family visits') ]).properties( width=500,height=500)

l6=alt.Chart(to).mark_line(color='Green').encode(x='Months', y='Total',tooltip=[
        alt.Tooltip('Months:O', title='Months'),
        alt.Tooltip('Total:Q', title='Total') ]).properties( width=500,height=500)
l1+l2+l3+l4+l5+l6
# Out:
# alt.LayerChart(...)

# %% [markdown]
# As you can see this linechart it display each month and the total of number for vistings

# %%
b1=alt.Chart(to).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Religious"),
    color='Months',
   tooltip = 'Religious').interactive()
b2=alt.Chart(to).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Business"),
    color='Months',
   tooltip = 'Business').interactive()
b3=alt.Chart(to).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Leisure"),
    color='Months',
   tooltip = 'Leisure').interactive()
b4=alt.Chart(to).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Other"),
    color='Months',
   tooltip = 'Other').interactive()
b5=alt.Chart(to).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Family visits"),
    color='Months',
   tooltip = 'Family visits').interactive()
b6=alt.Chart(to).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Total"),
    color='Months',
   tooltip = 'Total').interactive()
b1|b2|b3|b4|b5|b6
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# #### Reason to visit in which month
# - Januray was the highest month for religious between 1200 - 1300 visits
# - Januray was the highest month for Business between 250 - 400 visits
# - August and June was the highest month for Leisure between 3000 - 3450 visits
# - October and Januray was the highest month for other reasons between 145 - 170 visits
# - July was the highest month for Family visits between 3400 - 3450 visits

# %%
to.plot(x="Months", y=["Religious", "Business","Leisure","Other","Family visits"], 
        kind="bar", figsize=(20, 8))
 
# print bar graph
plt.show()

# %% [markdown]
# As you can see we colored every reason to vist and show us highest visits for each month and the reason

# %%
pd.DataFrame(to.max())
# Out:
#                        0
# Months         September
# Religious       1221.308
# Business         279.012
# Leisure         3406.026
# Other            165.504
# Family visits   3447.868
# Total           6793.111

# %% [markdown]
# Diplay the maximum for each reason

# %%
pd.DataFrame(to.min())
# Out:
#                       0
# Months            April
# Religious       397.796
# Business        121.091
# Leisure        1904.721
# Other            64.337
# Family visits  1313.591
# Total          4074.237

# %% [markdown]
# Display the manimum for each reason

# %%
pr = to[['Months','Total']].groupby(['Months']).sum()
pr['percent']=round( (pr['Total'] / pr['Total'].sum()) * 100 ,2)
pr.reset_index(inplace=True)
pr
# Out:
#       Months     Total  percent
# 0      April  4396.024     8.38
# 1     August  5521.794    10.53
# 2   February  5448.126    10.39
# 3    January  5855.511    11.16
# 4       July  6793.111    12.95
# 5       June  6541.266    12.47
# 6      March  4369.004     8.33
# 7        May  4074.237     7.77
# 8    October  4954.780     9.45
# 9  September  4499.355     8.58

# %% [markdown]
# Diplay the precent for each month

# %%
pr['percent'].sum()
# Out:
# 100.01

# %% [markdown]
# Diplay the sum for precent

# %%
base = alt.Chart(pr).mark_arc().encode(
    theta=alt.Theta("mean(Total):Q", stack=True),
    color=alt.Color("Months:N")
).properties(title="PieChart for percent for each month ",width=500,height=500)

pie = base.mark_arc(outerRadius=160)
text = base.mark_text(radius=190, size=12).encode(text="percent:N")
pie + text
# Out:
# alt.LayerChart(...)

# %% [markdown]
# This pichart diplay the percentage for each month

# %%
tyb1=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Albaha"),
    color='Months',
   tooltip = 'Albaha')
tyb2=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Alqassim"),
    color='Months',
   tooltip = 'Alqassim')
tyb3=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Aseer"),
    color='Months',
   tooltip = 'Aseer')
tyb4=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Eastern"),
    color='Months',
   tooltip = 'Eastern')
tyb5=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Hail"),
    color='Months',
   tooltip = 'Hail')
tyb6=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Jazan"),
    color='Months',
   tooltip = 'Jazan')
tyb7=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Jouf"),
    color='Months',
   tooltip = 'Jouf')
tyb8=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Madinah"),
    color='Months',
   tooltip = 'Madinah')
tyb9=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Makkah"),
    color='Months',
   tooltip = 'Makkah')
tyb10=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Najran"),
    color='Months',
   tooltip = 'Najran')
tyb11=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Northern Borders"),
    color='Months',
   tooltip = 'Northern Borders')
tyb12=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Riyadh"),
    color='Months',
   tooltip = 'Riyadh')
tyb13=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Tabuk"),
    color='Months',
   tooltip = 'Tabuk')
tyb14=alt.Chart(ty).mark_bar().encode(
   x = alt.X("Months"), 
   y = alt.Y("Total"),
    color='Months',
   tooltip = 'Total')

tyb1|tyb2|tyb3|tyb4|tyb5|tyb6|tyb7|tyb8|tyb9|tyb10|tyb11|tyb12|tyb13|tyb14
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# This chart diplay how many visit for each region and in which month

# %%
ty.plot(x="Months", y=["Tabuk", "Riyadh","Northern Borders","Najran","Makkah","Madinah","Jouf","Jazan","Hail","Eastern","Aseer","Alqassim","Albaha"], 
        kind="bar", figsize=(22, 5))
 
# print bar graph
plt.show()

# %% [markdown]
# This chart diplay which region have the most visits and in which month

# %% [markdown]
# ## <font color = Orange > Our Conclusion : </font>
# - The sum of the hotels prices was for Makkah province
# - The highest average for the hotels prices was in Riyadh province
# - The most higher hotels price was for Eastren province
# - Riyadh it is the highest vitis in July was above 2000
# - In Makkah province Jeddah was the higher city that people come to and spend there money
# - In Al Madinah province Al Madinah city was the higher city that people come to and spend there money
# - In Eastren province Dammam and Al Khobar was the higher city that people come to and spend there money
# - In Riyadh province Riyadh was the higher city that people come to and spend there money
# - In Al Jouf province Sakakah and Al Jouf was the higher city that people come to and spend there money
# - In Asser province Abha was the higher city that people come to and spend there money
# - In Qassim province Buraydah was the higher city that people come to and spend there money
# - In Broders province Turayf was the higher city that people come to and spend there money
# - In Hail province Hail was the higher city that people come to and spend there money
# - In Najjran province Najjran was the higher city that people come to and spend there money
# - In Tabuk province Umm Lajj and Tabuk was the higher city that people come to and spend there money
# - In Jizan province Jazan was the higher city that people come to and spend there money
# - In Al Baha province Al Baha was the higher city that people come to and spend there money
# - In the Makkah region, the city of King Abdullah Economic City got an average price of 900 riyals
# - In the Al Madinah region, the city of Madain Saleh got an average price of 1600 riyals
# - In the Eastern region, the city of Al Khobar got an average price of 500 riyals
# - In the Ryiadh region, the city of Riyadh got an average price of 400 riyals
# - In the Al Jouf region, the city of Al Qurayyat got an average price of 200 riyals
# - In the Asser region, the city of Bishah got an average price of 330 riyals
# - In the Al Qassim region, the city of Buraydah got an average price of 330 riyals
# - In the Northem borders region, the city of Turayf got an average price of 160 riyals
# - In the Hail region, the city of Hail got an average price of 230 riyals
# - In the Najjran region, the city of Najjran got an average price of 200 riyals
# - In the Tabuk region, the city of Umm Lajj got an average price of 470 riyals
# - In the Jizan region, the city of Fayfa got an average price of 650 riyals
# - In the Al Baha region, the city of Al Baha got an average price of 300 riyals
# -  Makkah province is most province that people spend money
# -  Ryiadh province is the highest average between the regions
# - Januray was the highest month for religious between 1200 - 1300 visits
# - Januray was the highest month for Business between 250 - 400 visits
# - August and June was the highest month for Leisure between 3000 - 3450 visits
# - October and Januray was the highest month for other reasons between 145 - 170 visits
# - July was the highest month for Family visits between 3400 - 3450 visits
# - that most reason for visiting  Saudi arabia is Leisure
# - that most regions for visiting Saudi arabia is Makkah

# %% [markdown]
# #### <font color = Purple > Answers for our questions </font>
#
# - In order to increase the income of Saudi Arabia in tourism and keep pace with other countries and progress to make Saudi Arabia at the forefront of choices for tourists.
# - Compare prices with regions of Saudi Arabia, the reasons for tourists visiting each month, and the months in which the number of tourists increases.
# - The main reason for visiting the Kingdom was for entertainment, followed by family visits. We have to take care and develop them and further develop the rest of the reasons and take care of them in order to raise the percentage of tourism.
# - The highest city visited is Mecca, followed by the capital, Riyadh.
# - Through the graphics you can know your destination in compare to your budget.

# %% [markdown]
# ## <font color = green> recommendation : </font>
#
# - The goal is to increase entertainment in Saudi Arabia
# - Improving and increasing the quality of hotels in Saudi Arabia
# - Presenting offers to tourists in order to bring them for a walk and take advantage of the monuments
# - Take advantage of antiquities and turn them into tourist attractions
# - Creating an entertaining ambience to attract tourists in Saudi Arabia
# - Develop and increase financial support for the Ministry of Tourism in Saudi Arabia
# - Take advantage of the products that attract the attention of tourists and expand their manufacture and development
